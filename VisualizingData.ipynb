# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
#load Audio files

# %%
pwd
# Out:
# 'C:\\Users\\Struth\\Desktop\\Minor'

# %%
file_path = "C:\\Users\\Struth\\Desktop\\Minor\\virufy_data-main\\clinical\\original\\neg\\neg-0421-083-cough-m-53.mp3"
x, Sr = librosa.load(file_path)
# Out:
# C:\Users\Struth\anaconda3\envs\tendf\lib\site-packages\librosa\core\audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
x.size
# Out:
# 404544

# %%
x
# Out:
# array([ 0.        ,  0.        ,  0.        , ..., -0.00014956,
#        -0.00031608, -0.00042012], dtype=float32)

# %%
#duration of 1 sample

# %%
s_dr = 1 / Sr

# %%
s_dr
# Out:
# 4.5351473922902495e-05

# %%
#duration of audio signal in second
duration = s_dr*len(x)

# %%
duration
# Out:
# 18.346666666666668

# %%
#visualize the signal

# %%
plt.figure(figsize=(15,17))
plt.subplot(3,1,1)
librosa.display.waveplot(x)
plt.title("Negative")
# Out:
# Text(0.5, 1.0, 'Negative')

# %%
pos_path = "C:\\Users\\Struth\\Desktop\\Minor\\virufy_data-main\\clinical\\original\\pos\\pos-0421-084-cough-m-50.mp3"
x_pos , Sr_pos = librosa.load(pos_path)
# Out:
# C:\Users\Struth\anaconda3\envs\tendf\lib\site-packages\librosa\core\audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
plt.figure(figsize=(15,17))
plt.subplot(3,1,1)
librosa.display.waveplot(x_pos)
plt.title("Positive")
# Out:
# Text(0.5, 1.0, 'Positive')

# %%
plt.figure(figsize=(15,17))
plt.subplot(3,1,1)
librosa.display.waveplot(x)
plt.title("Negative")

plt.subplot(3,1,1)
librosa.display.waveplot(x_pos)
plt.title("Positive")
plt.show()
# Out:
# C:\Users\Struth\anaconda3\envs\tendf\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
#calculate the amplitude
import numpy as np
def Ampli(signal , frame_size):
    ampli = []
    for i in range(0,len(signal),frame_size):
        current_frame_ampli = max(signal[i:i+frame_size])
        ampli.append(current_frame_ampli)
    return np.array(ampli)
#here frame_size is the second variable we are geting after loading audio files
#Basically it is sampling rate 
#we are taking max value in each sample rate to get amplitude

# %%
Ampli_pos = Ampli(x_pos,Sr_pos)

# %%
len(Ampli_pos)
# Out:
# 18

# %%
Ampli_neg = Ampli(x,Sr)

# %%
len(Ampli_neg)
# Out:
# 19

# %%
print("Positive              Negative")
for i in range(len(Ampli_pos)): 
    print(Ampli_pos[i],"           ",Ampli_neg[i])
# Out:
# Positive              Negative
# 0.20112173             0.03021901
# 0.72918195             0.78060335
# 0.0013931548             0.038286008
# 0.7105312             0.7266707
# 0.0010113176             0.018437313
# 0.7157657             0.73377335
# 0.43530828             0.64987314
# 0.724653             0.73739374
# 0.3905999             0.92997015
# 0.7203867             0.6960219
# 0.6983748             0.77698034
# 0.69174063             0.69840646
# 0.69279057             0.7291676
# 0.7810546             0.6875244
# 0.694287             0.72302514
# 0.0013455182             0.0633133
# 0.7319723             0.721181
# 0.14995575             0.010194468

# %%
plt.subplot(3,1,1)
librosa.display.waveplot(Ampli_pos,alpha=0.5)
plt.title("Positive")
plt.show()

# %%
frames = range(0,Ampli_neg.size-1)
t = librosa.frames_to_time(frames,hop_length= Sr)
plt.subplot(3,1,1)
librosa.display.waveplot(x_pos)
plt.plot(t,Ampli_pos)
plt.title("Negative")
plt.show()

# %%
t= list(range(0, 18))
plt.plot(t,Ampli_pos)

# %%
t= list(range(0, 19))
plt.plot(t,Ampli_neg)

# %%
rms_neg = librosa.feature.rms(y=x)

# %%
rms_neg
# Out:
# array([[0.00000000e+00, 8.05720845e-07, 1.30871165e-04, 3.72518203e-04,
#         4.30801738e-04, 4.60992509e-04, 4.91734070e-04, 4.02312289e-04,
#         3.95257870e-04, 4.03024082e-04, 3.81617952e-04, 3.86461674e-04,
#         3.71698261e-04, 3.51960771e-04, 3.72702983e-04, 3.51877243e-04,
#         3.35837045e-04, 3.33920470e-04, 3.33803211e-04, 3.60113045e-04,
#         3.81509133e-04, 3.92527145e-04, 3.86253028e-04, 3.50841176e-04,
#         3.23894928e-04, 1.43088796e-03, 3.86517053e-03, 4.09067143e-03,
#         4.14004922e-03, 3.92006291e-03, 1.58342230e-03, 8.66753224e-04,
#         6.49467169e-04, 5.31292171e-04, 5.14831219e-04, 5.02773211e-04,
#         4.36790258e-04, 4.00472200e-04, 3.71676550e-04, 3.67776578e-04,
#         3.47210938e-04, 3.33579374e-04, 3.39013408e-04, 3.93118069e-04,
#         4.88716352e-04, 5.22160961e-04, 5.04935742e-04, 4.37698938e-04,
#         3.28149588e-04, 1.22091651e-03, 6.69700429e-02, 1.43992648e-01,
# ...

# %%
rms_pos = librosa.feature.rms(y=x_pos)

# %%
rms_pos
# Out:
# array([[0.00000000e+00, 8.04812089e-07, 1.60970166e-03, 3.22503364e-03,
#         5.65746659e-03, 1.04080895e-02, 2.43428517e-02, 3.20455991e-02,
#         3.35428379e-02, 3.25278789e-02, 2.43013240e-02, 1.31013459e-02,
#         1.25629576e-02, 2.02627163e-02, 2.53454614e-02, 2.64841989e-02,
#         2.79341172e-02, 2.59243641e-02, 2.24525016e-02, 2.07069907e-02,
#         1.57041922e-02, 9.67092719e-03, 3.44180479e-03, 9.85477865e-03,
#         3.37887928e-02, 4.71093617e-02, 4.86811623e-02, 4.78079394e-02,
#         3.52146253e-02, 1.27451839e-02, 3.29731777e-03, 1.86914834e-03,
#         1.51543773e-03, 1.60620175e-03, 1.65344146e-03, 1.53704826e-03,
#         1.39628060e-03, 1.06177712e-03, 1.02607370e-03, 1.43880537e-03,
#         1.96082774e-03, 2.16882769e-03, 2.12395168e-03, 1.85805839e-03,
#         1.27768936e-03, 9.02567932e-04, 7.21504330e-04, 6.69949572e-04,
#         8.11147213e-04, 7.54542649e-04, 7.20837619e-04, 6.90346118e-04,
# ...

# %%
rms_neg.size
# Out:
# 791

# %%
arr = [[0]*791]*1
j = 1
for i in range(791):
    arr[0][i] = j
    j = j+1
grr = [[0]*765]*1
j=1
for i in range(765):
    grr[0][i] = j
    j = j+1

# %%
alpha = np.array(arr)
beta = np.array(rms_neg)
gamma = np.array(rms_pos)
theta = np.array(grr)

# %%
plt.plot(alpha,beta,'o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(theta,gamma,'o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
